# %%
#Dependencies:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from scipy.stats import linregress
import time
import json
import os
from pathlib import Path
import hvplot.pandas

#Files to load
airline_data_to_load = Path("Resources/airlines.csv")
airport_data_to_load = Path("Resources/airports.csv")
flights_data_to_load = Path("Resources/flights200501.csv")

#Read the data and store it in a Pandas dataframe
airline_data = pd.read_csv(airline_data_to_load)
airport_data = pd.read_csv(airport_data_to_load)
flights_data = pd.read_csv(flights_data_to_load)

#Clean the data to have same column names
airline_data.rename(columns={"AIRLINE": "AIRLINE_NAME"}, inplace=True)
airline_data.rename(columns={"IATA_CODE": "AIRLINE"}, inplace=True)
airport_data.rename(columns={"IATA_CODE": "ORIGIN_AIRPORT"}, inplace=True)

#Combine the data into a single dataframe
flight_data_complete = pd.merge(flights_data, airline_data, on="AIRLINE", how="left")
flight_data_complete = pd.merge(flight_data_complete, airport_data, on="ORIGIN_AIRPORT", how="left")
flight_data_complete
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4      AS             98      N407AS
# 1       2015      1    1            4      AA           2336      N3KUAA
# 2       2015      1    1            4      US            840      N171US
# 3       2015      1    1            4      AA            258      N3HYAA
# 4       2015      1    1            4      AS            135      N527AS
# ...      ...    ...  ...          ...     ...            ...         ...
# 469963  2015      1   31            6      B6            839      N658JB
# 469964  2015      1   31            6      DL           1887      N855NW
# 469965  2015      1   31            6      F9            300      N218FR
# 469966  2015      1   31            6      F9            422      N954FR
# 469967  2015      1   31            6      UA           1104      N73251
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0                 ANC                 SEA                    5  ...
# 1                 LAX                 PBI                   10  ...
# 2                 SFO                 CLT                   20  ...
# 3                 LAX                 MIA                   20  ...
# 4                 SEA                 ANC                   25  ...
# ...               ...                 ...                  ...  ...
# 469963            JFK                 BQN                 2359  ...
# 469964            SEA                 DTW                 2359  ...
# 469965            DEN                 TPA                 2359  ...
# 469966            DEN                 ATL                 2359  ...
# 469967            ANC                 DEN                 2359  ...
#
#         AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0                 NaN                  NaN            NaN
# 1                 NaN                  NaN            NaN
# 2                 NaN                  NaN            NaN
# 3                 NaN                  NaN            NaN
# 4                 NaN                  NaN            NaN
# ...               ...                  ...            ...
# 469963            NaN                  NaN            NaN
# 469964            NaN                  NaN            NaN
# 469965            2.0                  0.0            0.0
# 469966            0.0                  0.0            0.0
# 469967            NaN                  NaN            NaN
#
#                   AIRLINE_NAME  \
# 0         Alaska Airlines Inc.
# 1       American Airlines Inc.
# 2              US Airways Inc.
# 3       American Airlines Inc.
# 4         Alaska Airlines Inc.
# ...                        ...
# 469963         JetBlue Airways
# 469964    Delta Air Lines Inc.
# 469965  Frontier Airlines Inc.
# 469966  Frontier Airlines Inc.
# 469967   United Air Lines Inc.
#
#                                                   AIRPORT           CITY  \
# 0             Ted Stevens Anchorage International Airport      Anchorage
# 1                       Los Angeles International Airport    Los Angeles
# 2                     San Francisco International Airport  San Francisco
# 3                       Los Angeles International Airport    Los Angeles
# 4                    Seattle-Tacoma International Airport        Seattle
# ...                                                   ...            ...
# 469963  John F. Kennedy International Airport (New Yor...       New York
# 469964               Seattle-Tacoma International Airport        Seattle
# 469965                       Denver International Airport         Denver
# 469966                       Denver International Airport         Denver
# 469967        Ted Stevens Anchorage International Airport      Anchorage
#
#         STATE  COUNTRY  LATITUDE  LONGITUDE
# 0          AK      USA  61.17432 -149.99619
# 1          CA      USA  33.94254 -118.40807
# 2          CA      USA  37.61900 -122.37484
# 3          CA      USA  33.94254 -118.40807
# 4          WA      USA  47.44898 -122.30931
# ...       ...      ...       ...        ...
# 469963     NY      USA  40.63975  -73.77893
# 469964     WA      USA  47.44898 -122.30931
# 469965     CO      USA  39.85841 -104.66700
# 469966     CO      USA  39.85841 -104.66700
# 469967     AK      USA  61.17432 -149.99619
#
# [469968 rows x 38 columns]

# %%
#Clean the data and fill the missing values with 0
flight_data_cleaned=flight_data_complete.fillna("0")
flight_data_cleaned
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4      AS             98      N407AS
# 1       2015      1    1            4      AA           2336      N3KUAA
# 2       2015      1    1            4      US            840      N171US
# 3       2015      1    1            4      AA            258      N3HYAA
# 4       2015      1    1            4      AS            135      N527AS
# ...      ...    ...  ...          ...     ...            ...         ...
# 469963  2015      1   31            6      B6            839      N658JB
# 469964  2015      1   31            6      DL           1887      N855NW
# 469965  2015      1   31            6      F9            300      N218FR
# 469966  2015      1   31            6      F9            422      N954FR
# 469967  2015      1   31            6      UA           1104      N73251
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0                 ANC                 SEA                    5  ...
# 1                 LAX                 PBI                   10  ...
# 2                 SFO                 CLT                   20  ...
# 3                 LAX                 MIA                   20  ...
# 4                 SEA                 ANC                   25  ...
# ...               ...                 ...                  ...  ...
# 469963            JFK                 BQN                 2359  ...
# 469964            SEA                 DTW                 2359  ...
# 469965            DEN                 TPA                 2359  ...
# 469966            DEN                 ATL                 2359  ...
# 469967            ANC                 DEN                 2359  ...
#
#        AIRLINE_DELAY LATE_AIRCRAFT_DELAY WEATHER_DELAY  \
# 0                  0                   0             0
# 1                  0                   0             0
# 2                  0                   0             0
# 3                  0                   0             0
# 4                  0                   0             0
# ...              ...                 ...           ...
# 469963             0                   0             0
# 469964             0                   0             0
# 469965           2.0                 0.0           0.0
# 469966           0.0                 0.0           0.0
# 469967             0                   0             0
#
#                   AIRLINE_NAME  \
# 0         Alaska Airlines Inc.
# 1       American Airlines Inc.
# 2              US Airways Inc.
# 3       American Airlines Inc.
# 4         Alaska Airlines Inc.
# ...                        ...
# 469963         JetBlue Airways
# 469964    Delta Air Lines Inc.
# 469965  Frontier Airlines Inc.
# 469966  Frontier Airlines Inc.
# 469967   United Air Lines Inc.
#
#                                                   AIRPORT           CITY  \
# 0             Ted Stevens Anchorage International Airport      Anchorage
# 1                       Los Angeles International Airport    Los Angeles
# 2                     San Francisco International Airport  San Francisco
# 3                       Los Angeles International Airport    Los Angeles
# 4                    Seattle-Tacoma International Airport        Seattle
# ...                                                   ...            ...
# 469963  John F. Kennedy International Airport (New Yor...       New York
# 469964               Seattle-Tacoma International Airport        Seattle
# 469965                       Denver International Airport         Denver
# 469966                       Denver International Airport         Denver
# 469967        Ted Stevens Anchorage International Airport      Anchorage
#
#        STATE  COUNTRY  LATITUDE  LONGITUDE
# 0         AK      USA  61.17432 -149.99619
# 1         CA      USA  33.94254 -118.40807
# 2         CA      USA    37.619 -122.37484
# 3         CA      USA  33.94254 -118.40807
# 4         WA      USA  47.44898 -122.30931
# ...      ...      ...       ...        ...
# 469963    NY      USA  40.63975  -73.77893
# 469964    WA      USA  47.44898 -122.30931
# 469965    CO      USA  39.85841   -104.667
# 469966    CO      USA  39.85841   -104.667
# 469967    AK      USA  61.17432 -149.99619
#
# [469968 rows x 38 columns]

# %%
#Check to insure there are no null values
null_count= flight_data_cleaned.isnull().sum()
null_count
# Out:
# YEAR                   0
# MONTH                  0
# DAY                    0
# DAY_OF_WEEK            0
# AIRLINE                0
# FLIGHT_NUMBER          0
# TAIL_NUMBER            0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_TIME         0
# DEPARTURE_DELAY        0
# TAXI_OUT               0
# WHEELS_OFF             0
# SCHEDULED_TIME         0
# ELAPSED_TIME           0
# AIR_TIME               0
# DISTANCE               0
# WHEELS_ON              0
# TAXI_IN                0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# CANCELLATION_REASON    0
# AIR_SYSTEM_DELAY       0
# SECURITY_DELAY         0
# AIRLINE_DELAY          0
# LATE_AIRCRAFT_DELAY    0
# WEATHER_DELAY          0
# AIRLINE_NAME           0
# AIRPORT                0
# CITY                   0
# STATE                  0
# COUNTRY                0
# LATITUDE               0
# LONGITUDE              0
# dtype: int64

# %%
#What is the average delay time for each airline

#Create a new dataframe that contains the airline delays that are greater than zero
flight_data_cleaned['AIRLINE_DELAY'] = flight_data_cleaned['AIRLINE_DELAY'].astype(float)
flights_delayed_df = flight_data_cleaned.loc[flight_data_cleaned['AIRLINE_DELAY'] > 0]
flights_delayed_df
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 35      2015      1    1            4      HA             17      N389HA
# 52      2015      1    1            4      B6           2134      N307JB
# 55      2015      1    1            4      B6           2276      N646JB
# 73      2015      1    1            4      US            425      N174US
# 74      2015      1    1            4      AA             89      N3KVAA
# ...      ...    ...  ...          ...     ...            ...         ...
# 469912  2015      1   31            6      B6           2002      N317JB
# 469920  2015      1   31            6      B6            912      N516JB
# 469924  2015      1   31            6      B6            729      N510JB
# 469940  2015      1   31            6      B6            688      N643JB
# 469965  2015      1   31            6      F9            300      N218FR
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 35                LAS                 HNL                  145  ...
# 52                SJU                 MCO                  400  ...
# 55                SJU                 BDL                  438  ...
# 73                PDX                 PHX                  520  ...
# 74                IAH                 MIA                  520  ...
# ...               ...                 ...                  ...  ...
# 469912            JFK                 BUF                 2310  ...
# 469920            LAS                 JFK                 2318  ...
# 469924            MCO                 BQN                 2325  ...
# 469940            LAX                 BOS                 2349  ...
# 469965            DEN                 TPA                 2359  ...
#
#        AIRLINE_DELAY LATE_AIRCRAFT_DELAY WEATHER_DELAY  \
# 35              15.0                 0.0           0.0
# 52              85.0                 0.0           0.0
# 55              72.0                 0.0           0.0
# 73              60.0                 0.0           0.0
# 74              54.0                 0.0           0.0
# ...              ...                 ...           ...
# 469912           8.0                 8.0           0.0
# 469920          18.0                 0.0           0.0
# 469924          15.0                25.0           0.0
# 469940          18.0                11.0           0.0
# 469965           2.0                 0.0           0.0
#
#                   AIRLINE_NAME  \
# 35      Hawaiian Airlines Inc.
# 52             JetBlue Airways
# 55             JetBlue Airways
# 73             US Airways Inc.
# 74      American Airlines Inc.
# ...                        ...
# 469912         JetBlue Airways
# 469920         JetBlue Airways
# 469924         JetBlue Airways
# 469940         JetBlue Airways
# 469965  Frontier Airlines Inc.
#
#                                                   AIRPORT         CITY STATE  \
# 35                         McCarran International Airport    Las Vegas    NV
# 52                 Luis Muñoz Marín International Airport     San Juan    PR
# 55                 Luis Muñoz Marín International Airport     San Juan    PR
# 73                         Portland International Airport     Portland    OR
# 74                   George Bush Intercontinental Airport      Houston    TX
# ...                                                   ...          ...   ...
# 469912  John F. Kennedy International Airport (New Yor...     New York    NY
# 469920                     McCarran International Airport    Las Vegas    NV
# 469924                      Orlando International Airport      Orlando    FL
# 469940                  Los Angeles International Airport  Los Angeles    CA
# 469965                       Denver International Airport       Denver    CO
#
#         COUNTRY  LATITUDE  LONGITUDE
# 35          USA  36.08036 -115.15233
# 52          USA  18.43942  -66.00183
# 55          USA  18.43942  -66.00183
# 73          USA  45.58872  -122.5975
# 74          USA  29.98047  -95.33972
# ...         ...       ...        ...
# 469912      USA  40.63975  -73.77893
# 469920      USA  36.08036 -115.15233
# 469924      USA  28.42889  -81.31603
# 469940      USA  33.94254 -118.40807
# 469965      USA  39.85841   -104.667
#
# [50754 rows x 38 columns]

# %%
#What is the average delay time for each airline

#Find the average delay time for each airline using groupby 
average_delay= flights_delayed_df.groupby(["AIRLINE"])["AIRLINE_DELAY"].mean()
average_delay
# Out:
# AIRLINE
# AA    39.939424
# AS    41.426724
# B6    25.107389
# DL    41.717744
# EV    40.692335
# F9    30.489459
# HA    22.239272
# MQ    35.863570
# NK    26.832232
# OO    50.677010
# UA    32.760287
# US    30.685219
# VX    31.059006
# WN    22.731691
# Name: AIRLINE_DELAY, dtype: float64

# %%
#What origin airports have the highest amount of delayed flights

#Find the average delay of each origin airport
origin_delay= flights_delayed_df.groupby(["ORIGIN_AIRPORT"])["AIRLINE_DELAY"].mean()
origin_delay
# Out:
# ORIGIN_AIRPORT
# ABE     30.214286
# ABI     46.720000
# ABQ     36.982857
# ABR    253.200000
# ABY     50.625000
#           ...
# VEL     96.000000
# VLD     43.777778
# VPS     45.791667
# XNA     63.076923
# YUM    102.200000
# Name: AIRLINE_DELAY, Length: 297, dtype: float64

# %%
#What origin airports have the highest amount of delayed flights

max_origin_delay= flights_delayed_df.groupby(["ORIGIN_AIRPORT"])["AIRLINE_DELAY"].max()
max_origin_delay
# Out:
# ORIGIN_AIRPORT
# ABE    176.0
# ABI    420.0
# ABQ    531.0
# ABR    916.0
# ABY    347.0
#        ...
# VEL     96.0
# VLD    136.0
# VPS    318.0
# XNA    605.0
# YUM    274.0
# Name: AIRLINE_DELAY, Length: 297, dtype: float64

# %%
#What destination airports have the highest amount of delayed flights

#Find the average delay of each destination airport
destination_delay= flights_delayed_df.groupby(["DESTINATION_AIRPORT"])["AIRLINE_DELAY"].mean()
destination_delay
# Out:
# DESTINATION_AIRPORT
# ABE    37.785714
# ABI    28.744186
# ABQ    23.734300
# ABR    41.000000
# ABY    65.400000
#          ...
# VPS    39.533333
# WRG    16.000000
# XNA    37.973913
# YAK     6.500000
# YUM    50.818182
# Name: AIRLINE_DELAY, Length: 310, dtype: float64
